# %% [markdown]
# <a href="https://colab.research.google.com/github/NikolayNikolaev1982/GzLM/blob/main/DOMANDE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DOMANDA A.1 MODELLO CON ERRORI ETEROSCHEDASTICI :  VALORE ATTESO E VARIANZA (2 PUNTI)
#
# Si consideri ora il modello con errori eteroschedastici e incorrelati
# $$y_i = X_iB + ε_i^*$$
#                                                    $$(1,1),  (1,p),(p,1)(1,1)$$
# Si considerino  gli errori relativi all'individuo  nella posizione $i$-esima  di ogni campione    $ε_{i1^*}, ε_{i2}^*, …, ε_{ik}^*$.Perciò le varianza degli errori relativi ad individui diversi sono diverse e il relativo modello diviene il modello lineare con errori eteroschedastici
# $$y_i = X_iB + ε_i^*$$
#
# con valore atteso e varianza degli errori:
# $$E(Ei*) = 0 $$
#
# $$Var(E_i^*) = E(E_{i2}^*) = 𝛔_{i}^2$$
# Invece si continua a ipotizzare incorrelazione tra gli errori
# $$Cor(E_i^*,E_k^*) = \frac{1}{n} (E_i^*,E_k^{*'}) = 0     $$

# %% [markdown]
# ## DOMANDA A.2 MATRICI ERRORI OMOSCHEDASTICI E INCORRELATI  ETEROSCHEDASTICI E INCORRELATI (1 PUNTO)
#
# Matrice degli errori eteroschedastici e incorrelati
# $$
# \operatorname{Var}(\boldsymbol{\varepsilon}) =
# \boldsymbol{\Omega} =
# \begin{bmatrix}
# \sigma_1^2 & 0 & \cdots & 0 \\
# 0 & \sigma_2^2 & \cdots & 0 \\
# \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & \cdots & \sigma_n^2
# \end{bmatrix}
# $$
#
# omoschedastici e incorrelati
# $$
# \operatorname{Var}(\boldsymbol{\varepsilon}) =
# \boldsymbol{\Omega} =
# \sigma^2 \mathbf{I}_n =
# \sigma^2
# \begin{bmatrix}
# 1 & 0 & \cdots & 0 \\
# 0 & 1 & \cdots & 0 \\
# \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & \cdots & 1
# \end{bmatrix}
# $$

# %% [markdown]
# ## DOMANDA A.3 ERRORI ETEROSCHEDASTICI: STIMATORI CORRETTI   (1 PUNTO)
#
# L' errore eteroschedastico è caratterizzato da una variabilità che dipende dall'istante di rilevazione del fenomeno o dal tipo di legame studiato e su che supporto (es. persone umane).
#
# Vale   la  correttezza  che non dipende  da omoschedasticità.
# Dato  lo stimatore eteroschedastico $B*$
# $$E[B*]= E(X’X)^{-1}X’ y= (X’X)^{ -1}X E(y)= (X’X)^{ -1}X’ E(X b+ e*)= $$
# $$(X’X)^{-1}(X’ X)  E(b)= b        $$
# Vale anche linearità e consistenza

# %% [markdown]
# ## DOMANDA A.4 ERRORI ETEROSCHEDASTICI :   STIMATORI  EFFICIENTI ( 2 PUNTI)
#
# Gli stimatori  non  sono  più BLUE e quindi  non più efficienti. Infatti:
# $$Var (B^*)=E(((X'X)^{-1}X')y-b)( (X'X)^{-1}X')y-b))'=$$
# $$E(((X'X)^{-1}X')(Xb+e^*)-b)((X'X)^{-1}X')(Xb+e^*)-b))=$$
# $$E(( (X'X)^{-1}X')e^*)((X'X)^{-1}X')e^*)'=(X'X)^{-1}X')E(e^*e^{*'})(X'X)^{-1}X' )' =((X'X)^{-1} X')$$
# $$Σe^*((X'X)^{-1}X')'$$
#
# ## DOMANDA A.5 REGIONE DI RIFIUTO  DEL TEST SUI PARAMETRI CON ERRORI ETEROSCHEDASTICI    ( 1 PUNTO)
#
# La conseguenza della non efficienza della stima OLS dei parametri è che  la  varianza campionaria $s_g^2$  sottostima il vero valore di $σ_2$
# La  regione di rifiuto è più grande di quanto non sia in realtà  e   i parametri sono significativi  anche quando non lo sono in realtà. Gli  Intervalli di confidenza costruiti  sono più piccoli  di quanto non siano in realtà
#
# ## DOMANDA A.6   INDIVIDUAZIONE ETEROSCHEDASTICITA’: SCATTER PLOT (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.7 INDIVIDUAZIONE ETEROSCHEDASTICITA’: VALORI OSSERVATI VS PREDETTI (1 PUNTO)
#
# **Eteroscedasticita**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ** Omoscedasticita**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##                                  DOMANDA A.8  TEST DI WHITE ( 1 PUNTO)
#
# $$H_0:    Var (ε|X) =σ^2 I_n)\text{ vs. }H_1:    Var (ε|X) ≠ σ^2 I_n)$$
# regressione OLS del quadrato dei residui  $(ε^2)$ sugli  $x, x^2$ e tutte le loro  interazioni
# $$ε_i^2=γ_0+γ_1x_{i1}+...+γ_px_{ip}+γ_αx_{i1}^2+γ_βx_{i2}^2+...+γ_ζx_{ik}+γ_θx_{i1}x_{i2}+...+γ_κx_{i1}x_{ik}+...+γ_νx_{i2}x_{ik} +u_i$$
# Costruzione di statistica LM basata su $R^2$ coeff. det multiplo della   regressione $LM =nR^2$
# distribuita  come una $χ^2$ con gradi di libertà pari a $n$ regressori. Se cade nella regione di rifiuto è respinta ipotesi di omoschedasticità
#
# ## DOMANDA A.9 MODELLO CON ERRORI CORRELATI  :  VALORE ATTESO E VARIANZA (2 PUNTI)
#
# $$y_j=x_j B^\# + ε_j^\#$$
# $$ E( E_i^\#) = 0 $$
# $$Var(E_j^\#) = E(E_j^{2^\#}) = 𝛔^2$$
# $$Cor(E_j^\#, E_k^\#) = \frac{1}{n}(Ej^\# E_k'^\#) = ρ_{jk}$$
#
# ## DOMANDA A.10  MATRICE DI VARIANZE DI ERRORI OMOSCHEDASTICI E CORRELATI  (1 PUNTO)
# $$
# \operatorname{Var}(\boldsymbol{\varepsilon}) =
# \boldsymbol{\Omega} =
# \sigma^2 \mathbf{R}
# \quad \text{con} \quad
# \mathbf{R} =
# \begin{bmatrix}
# \sigma^2 & \rho & \rho & \cdots & \rho \\
# \rho & \sigma^2 & \rho & \cdots & \rho \\
# \rho & \rho & \sigma^2 & \cdots & \rho \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# \rho & \rho & \rho & \cdots & \sigma^2
# \end{bmatrix}
# $$

# %% [markdown]
# ## DOMANDA A.11  AUTOCORRELAZIONE POSITIVA E NEGATIVA  (1 PUNTO)
# **Autocorrelazione positiva** : al variare di $x$ varia  $y$ con lo stesso segno oltre un certo intervallo di confidenza; negativa al variare di $x$ varia  $y$ con segno alternato oltre un certo intervallo di confidenza
#
# ## DOMANDA A.12 AUTOCORRELAZIONE  DI GRADO SUPERIORE AL 1^  (1 PUNTO)
#
# L’autocorrelazione  può essere di grado superiore  al primo
# $$e_i^\# = ρ ε_{i −2}^\#+ η_i \tag{ 2^ grado}$$
# $$e_i^\# = ρ ε_{i −3}^\#+ η_i \tag{ 3^ grado}$$
# $$e_i^\# = ρ ε_{i −s}^\#+ η_i \tag{ s^ grado}$$
#
#
# ## DOMANDA A.13 ERRORI  CORRELATI :  CORRETTEZZA STIMATORI ( 1 PUNTO)
# Valgono   correttezza e la linearità che non dipendono  da autocorrelazione. Dato lo stimatore con osservazioni autocorrelate B#
# $$E[B] = E(X'X)^{-1}X' y = (X'X)^{-1}X E(y) = (X'X)^{ -1}X'E(Xb + e^\#)= (X'X) ^{-1}X'X  E(b)= b$$
#   Si dimostra vale anche la consistenza
#
#
# ## DOMANDA A.14 ERRORI  CORRELATI:   EFFICIENZA  STIMATORI ( 3 PUNTI)
#
# Lo Stimatore $B^\#$ con errori correlati non è più BLUE e quindi  efficiente
# $$Var (B^\#)=E(((X'X)^{-1}X')y-b)( (X'X)^{-1}X')y-b))'=$$
# $$E(((X’X)^{-1}X’)(Xb+e^\#)-b)((X’X)^{-1}X’)(Xb+e^\#)-b))=$$
# $$E(((X’X)^{-1}X’)e^\#)((X’X)^{-1}X’)e^\#)’=    $$
# $$(X'X)^{-1}X')E(e^\#e^{\#’})(X’X)^{-1}X’ )’ =$$
# $$ ((X’X)^{-1} X’)Σe^\# ((X’X)^{-1}X’)’$$
#
#
# ## DOMANDA A.15 REGIONE RIFIUTO DEI TEST  SUI PARAMETRI  CON ERRORI CORRELATI ( 1 PUNTO)
#
# La conseguenza della non efficienza della  stima della varianza campionaria $s^2$ è che  non è usabile nella $T$ di Student   perché  $T$  è costruita sulla base di incorrelazione degli errori.  La  regione di rifiuto è più grande di quanto non sia in realtà  e   i parametri sono significativi  anche quando non lo sono in realtà. Gli  Intervalli di confidenza costruiti  sono più piccoli  di quanto non siano in realtà
#
# ## DOMANDA A.16   INDIVIDUAZIONE CORRELAZIONE: RESIDUI VS VARIABILI  (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.17   INDIVIDUAZIONE CORRELAZIONE: CORRELOGRAMMA  (1 PUNTO)

# %% [markdown]
# ## DOMANDA A.17   INDIVIDUAZIONE CORRELAZIONE: CORRELOGRAMMA  (1 PUNTO)
#
# Residui con lag temporale: autocorrelazione seriale. La banda di confidenza mostra il limite entro cui non c’è autocorrelazione

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.18   STATISTICA  DI DURBIN-WATSON  (4 PUNTI)
#
# Statistica   DW
#
# $$DW= \frac{Σ_i (ε_i^\#-ε_{i-1}^\#)^2 }{ Σ_i ε_i^{\#2}}=$$
# (i=2,…,n )
# $$\frac{(E(ε_i^\#)^2+E(ε_{i-1}^\#)^2-2E(ε_i^\#, ε_{i-1}^\#)) }{ E(ε_i^\#)^2} 	$$
# Per l’omoschedasticità dei residui al numeratore abbiamo  :
# $$E(ε_{i-1}^{\#2}) =var (ε_{i-1}^\#) =E(ε_i^\#) = var (ε_i^\#) = σ_i^2= σ^2$$
# e essendo   $$E (ε_i^\#, ε_{i-1}^\#) =E (ρε_{i-1}^\#+ η_i , ε_{i-1}^\#) = ρσ^2 + E(η_i , ε_{i-1}^\#) =$$
# in quanto per le proprietà della regressione $E(η_i , ε_{i-1}^\#)=0$.
# Al denominatore abbiamo $$var(ε_{i-1}^\#) = var(ε_i^\#) = σ^2$$   Perciò   $$DW= \frac{(2σ$2-2ρσ$2)}{ σ^2} = 2(1-ρ)  	$$
#
# ## DOMANDA A.19   TEST  DI DURBIN-WATSON  (2 PUNTI)
# Test di  Durbin-Watson su errori campionari assenza di correlazione seriale del $1^\#$ ordine $H_0:ρ= Corr[ε_i^\#, ε_{i-1}^\#]=0$. 	La distribuzione campionaria di DW è centrata su 2 (DW=2, r=0)  se esiste incorrelazione; tende a 0 se i residui sono correlati positivamente (DW=0, ρ=1); tende a 4 se i residui sono correlati negativamente(DW=4, ρ=-1). I valori critici dipendono dai valori campionari delle X  e quindi variano di caso in caso. Per questo sono stati fissati valori critici pari a dl e du che delimitano regioni rifiuto da regioni di inconcludenza del test a regioni di accettazione. Quando non siano specificati dL e dU se d<1 è autocorrelazione positiva; se d>3  negativa Se d è tra 1 e 3 non autocorrelazione
#
#
# ## DOMANDA A.20   GRAFICO DI DURBIN-WATSON  (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.21 TRASFORMAZIONI PER  ERRORI ETEROSCHEDASTICI E INCORRELATI (3 PUNTI)
#
# $$y_i = x_iB^*+ε_i^*$$
# $$ε_i^{*2} = s_i^2$$
# $$Cov (ε_i^*, ε_j^*)= E(ε_i^*, ε_j^*) = 0 	\tag{∀i≠ j}$$
# Trasformazione delle variabili
# $$y_i+ = \frac{y_i}{s_i^{\frac{1}{2}}}$$
# $$_{ij}+ = \frac{x_{ij}}{s_i^{\frac{1}{2}}}$$
# $$\epsilon_i+ = \frac{\epsilon_i}{s_i^{\frac{1}{2}}}$$
# $$y+ = X^+B + ε+  $$
# che danno luogo al modello trasformato:
# $$y+ = X^+B + ε^+$$
# Stima del modello trasformato con il metodo OLS regredendo  $y+$ su $X^+$
#
# ## DOMANDA A.22 STIMA CON MINIMI QUADRATI PESATI (WLS) (2 PUNTI)
#
# Da $$y^+ = X^+B + ε^+$$
# si ottiene:
# $$y_i+ = \frac{y_i}{s_i^{1/2}}$$
# $$x_{ij}+ = \frac{x_{ij}}{s_i^{1/2}}$$
# $$ε_i += \frac{ε_i^*}{s_i^{1/2}}$$
#
# $$
# \frac{1}{n}y+’y+ = Σy^+ = B^{+'}\frac{1}{n}X+’X^+ B^+ + S_ε^{-1/2} S_ε S_ε^{-1/2} =$$
# $$B+’Σx^+B^+ + S_ε^{-1/2} S_ε S_ε^{-1/2} = B +’Σx^+B^+ + I_n	$$
#
#
#
# ## DOMANDA A.23  STIMA GLS NEL CASO DI AUTOCORRELAZIONE  MODO A STIMA DI ρ   ( 2 PUNTI)
#
# Dato il  modello lineare semplice con errori correlati tempo t
# $$y+t= \beta_0 +\beta_1x_t+ε_t^\#$$
# ove $ε_t^\#$ è l’errore al tempo $t$  si ha quindi per il tempo i
# $$y_i= \beta_0 +\beta_1x_i+ε_i^\#$$
# on $ε_i$^ correlato in termini di '$ρ$  autocorrelazione del 1° ordine con $ε_{i-1}^{o\#}$ Si ha infatti:
#
# $$ε_i^\#= a_0 + a_1^\#x_1 + a_2^\# x_2 + ...+ a_k^\# x_k+ ρ ε_{i-1}^{o\#} $$
#
#
# ## DOMANDA A.24  STIMA GLS NEL CASO DI AUTOCORRELAZIONE   ( 4 PUNTI)
#
#
#   Data l’ equazione ritardata
#   $$y_{i-1}= \beta_0 +\beta_1x_{i-1}+ε_{i-1}^\#$$
# moltiplicata per $\rho$ ricavato nella 1^parte della stima
#
# $$\rho y_{i-1}= \rho\beta_0+ \rho\beta_1x_{i-1}+\rhoε_{i-1}^\#$$
#
# la si sottrae alla
#
# $$y_t= \beta_0 +\beta_1 x_t+ε_t^\#$$
#
# $$y_i-\rho y_{i-1}= \beta-0 (1-\rho)+\beta_1(x_i-\rho x_{i-1} + w_i$$
#              con
# $$w_i=ε_i^\#-\rho ε_{i-1} ^\#$$
#
#
# $$y_i= \beta_0 (1-\rho)+\rho y_{i-1} +\beta_1 x_i-\beta_1 \rho x_{i-1} +w_i$$
#
#  e quindi -----
#           $$y_i^\# = \beta_0^\# + \beta_1 x_i^\# + w_i$$
# con :
# $$y_i^\#=y_i- \rho y_{i-1}$$
# $$\beta_0^\#=\beta_0 (1-\rho)$$
# $$x_i^\#=(x_i- \rho x_{i-1})$$
# Dato che i $w_i$ hanno anche essi valore atteso pari a 0:
# $$E (w_i )  = E (ε_i^\#-\rho ε_{i-1}^\#)= E (ε^\#)-\rho E(ε_{i-1}^\#)=0$$
#
# $$cov (w_i, w_{i-1})= 0$$
#
# ## DOMANDA A.25  STIMA MODELLO AUTOREGRESSIVO ( 3 PUNTI)
# Procedura di SAS: PROC AUTOREG, che incorpora automaticamente un modello autoregressivo per la componente d'errore
# Partendo da modello  con errori correlati
# $$y_t= \beta_0 +\beta_1 x_i+ε_t^\#$$
# Con modello autoregressivo di ordine 1 si introduce  tra le variabili esplicative il termine di errore ritardato AR1 che tiene conto della autocorrelazione di 1^ ordine :
# $$y_i=\beta_0+\beta_1 x_i + AR(1)_i+ε_i^\# = \beta_0+\beta_1x_i+ v_{i(1)}$$
# con $$v_{i(1)} = AR(1)_i+ε_i^\#$$
# in modo che $$E (v_{i(1)} , v_{i-1(1)} )  =0$$
# Nel modello autoregressivo di ordine 2 si introduce  tra le variabili esplicative anche  il termine di errore ritardato AR2 che tiene conto della autocorrelazione di 2^ ordine :
# $$y_i=\beta_0+\beta_1x_i+AR(1)_i+AR(2)_i +ε_i^\# = \beta_0+\beta_1x_i +v_{i(2)}$$
# con $$vi = AR(1)i+AR(2)i +εi^\#$$
# in modo che $$E (v_{i(2)} , v_{i-1(2)} )  = 0$$
# e così via per le autocorrelazioni di ordine $k=,1,2,…,v$

# %% [markdown]
# ## DOMANDA A.26  STIMA GLS CASO GENERALE : ERRORI TRASFORMATI ( 3 PUNTI)
#
# Il modello intende eliminare correlazione e eteroschedasticità
#
# In questo caso si utilizzano gli stimatori dei minimi quadrati generalizzati (GLS) interpretabili in modo analogo al modello classico quali  stimatori  OLS basati su variabili trasformate. Si ha:
#  $$y= XB^°+  E^°$$
# la matrice di varianze covarianze campionaria degli errori  è:
# $$\frac{1}{n} (E^{°}E^{°’})=SE^°$$
#
# Si ipotizzi  l’esistenza di una matrice $V_(n,n)$ non singolare tale che:
#   $$(SE^°)= σ2VV’ $$
#   $$(SE^°)^{-1}=(1/σ2) (V’)^{-1} (V)^{-1}$$
#   $$VV’ =(SE^°/ σ2 )$$
#
# Si definiscano gli errori trasformati $\hat{𝛆}$ tali che:$$\hat{E}=(\hat{V})^{-1} \hat{E}^°$$
#
#
# ## DOMANDA A.27  STIMA GLS CASO GENERALE: VARIABILI TRASFORMATE ( 3 PUNTI)
#
# Dato   $(S_{\hat{E}^°})= σ^2VV’$ con matrice $V_{(n,n)}$ non singolare
# $$(V)^{-1}S_{\hat{E}^°}(V)^{-1’}=(V)^{-1}σ^2VV’(V)^{-1’}=σ^2I_n$$
#
# $$V’ (S_{\hat{E}^°})^{-1}V=V’ (1/σ^2)(V’)^{-1}(V)^{-1}V= (1/σ^2)I_n)	$$
#
# Pre moltiplicando ambo i membri della  $(y= X\hat{B}^°+  \hat{E}^°$
# per $(V)^{-1} si ha il modello nelle variabili trasformate:
#
# $$(V)^{-1}y =y^{°}= (V)^{-1}XB +(V)^{-1} \hat{E}^° = X^°B  + \hat{E}$$

# %% [markdown]
# ## DOMANDA A.28  STIMA GLS CASO GENERALE ( 4 PUNTI)
#
# Applico la formula dei minimi quadrati a
# $$y^°= (V)^{-1}y = X^{°}B  + \hat{E} = (V)^{-1}XB +(V)^{-1} E^{°}$$
# Si ha:
# $$X^{°'}y^°= (X^{°'}X^{°} )B+ X^{°'}\hat{E}$$
#  Per l’incorrelazione fra regressori ed errori spiegata all’inizio
#
# $$X^{°'}E=0 $$
# $$X^{°'}y^°= (X^{°'}X^°) B$$
#
# Premoltiplicando per $(X^{°'}X^° )^{-1}$ entrambi i membri
# $$(X^{°'}X^{°} )^{-1} X^{°'}y^{°}= (X^{°'}X^{°} )^{-1} (X^{°'}X^{°}) B = B$$
#
# con:
# $$\hat{B}^°= (X^{°'}X^°)^{ -1} X^{o'}y^° = (X'S \hat{E}^{o-1} X)^{ -1}  X' S \hat{E}^{°-1} y$$
#
# stima dei minimi quadrati generalizzati GLS con matrice di varianze
#
# Si ha quindi ha come nel modello OLS
# $$Σ_{y^°}=B^{°’} Σ_{X^°}B^° +σ^2I_n$$
# Si dimostra che per le proprietà della  decomposizione spettrale della matrice $S_{\hat{E}^°}  V$ può essere ricavata  come suo autovettore
#
#
#
# ## DOMANDA A.29 STIMATORE GLS: CORRETTEZZA STIMATORI  ( 2 PUNTI)
#
# Lo stimatore GLS B° gode della proprietà di correttezza:
#
# $$B^° = (X^{°’}X^°)^{ -1} X^{°’}y^° =(X^{°’}X^°)^{ -1} X^{°’}(X^°b^° + E^°)=b^°+(X^{°’}X^°)^{-1}X^{°’}E^°$$
# $$E (B^°)=E (b^°+(X^{°’}X^°)^{-1}X^{°’}E^°)= b^° + (X^{°’}X^°)^{-1}X^{°’}E(E^°) = b^°$$

# %% [markdown]
# ## DOMANDA A.30 STIMATORE GLS: EFFICIENZA STIMATORI (4 PUNTI)
#
# Si dimostra il teorema di Aitken analogo al Gauss-Markov per gli stimatori OLS.  La  matrice varianze covarianze dello stimatore GLS  è:
#
# $$E ((B^°- b^°)^{'}(B^° - b^°)^{'}) =
# σ^2 (X^{°’} X^{°})^{-1} =σ^2 (X'Σ_{E^°}^{-1} X)^{-1}$$
# analoga a quella dell’efficienza per gli stimatori OLS con variabili $y,X$
#
# $$σ^2 (X°’X°)^{-1} - σ^2 (X ’X )^{-1}$$
# è matrice semidefinita positiva e quindi non è più  VUE nè BLUE. Tuttavia il teorema di Aitken stabilisce che nella classe degli stimatori lineari per il modello di regressione generalizzato lo stimatore GLS ha  minima  varianza e quindi  efficiente

# %% [markdown]
# ## Domanda A.31 MULTICOLLINEARITA’ ( 1 PUNTO)
#
# Multicollinearità: Quando  una variabile  o gruppi di variabili combinazione lineare  delle altre $X’X$  singolare  $(X’X)^-1$ non   invertibile    Non si hanno soluzioni uniche:
#
# Tuttavia una variabile può essere quasi collineare con 2 o più variabili (multicollineare) cioè rispettivamente fortemente correlata o quasi linearmente dipendente da altre. In tal caso le varianze dei parametri stimati tendono sono elevate:
#                                                        $$Var(\hat{B}) = σ^2(X’X)^{-1}  $$
#
# Con $\frac{1}{σ_{jj}^{-1}}$  elemento generico jj-esimo  di $(X’X)$

# %% [markdown]
# ## Domanda A.32 CONSEGUENZE MULTICOLLINEARITA’(3 PUNTI)
#
# 1) L’aumento della varianza delle stime dei coefficienti: al variare del campione le stime non sono stabili e variano moltissimo.
#
# Il risultato campionario è quindi molto meno attendibile.
#
# 2) Si consideri la t di di Student
# La  regione di accettazione è più larga di quanto debba essere e quindi aumenta la probabilità che un parametro  sia considerato  statisticamente non significativo anche quando in realtà lo è.
#
# Analogo ragionamento può essere fatto per il test F sui singoli parametri Anche l’intervallo di confidenza tende a  essere più largo  di quanto debba essere e quindi a parità di probabilità diminuisce la precisione della stima del vero valore del parametro nella popolazione
#
# ## DOMANDA A.33 MATRICE DI CORRELAZIONE, INDICE DI TOLLERANZA ( 1 PUNTO)
#
# Il primo modo per considerare la collinearità delle variabili è guardare la matrice di  correlazione.
#
# Questo offre un quadro della collinearità tra coppie di variabili attraverso il coefficiente di correlazione lineare (Quando maggiore di 0.9 indica alta correlazione)
#
# b) L’Indice di tolleranza (valore compreso tra 0 e 1) misura la multicollinearità: grado di dipendenze lineare  di una variabile esplicativa rispetto alle altre.
# $$Tol(x_j) = 1-R^2(\frac{x_j}{x_1, …, x_{j-1}, x_{j+1}, …, x_p})$$
# Quanto aumenta il legame con le altre tanto aumenta $Tol$
# Se una variabile è multicollineare
# $$R^2(\frac{x_j}{x_1, …, x_{j-1}, x_{j+1}, …, x_p}) = 1$$
#
# $$Tol(x_j) = 0$$
# Se è incorrelata con  tutte le altre
# $$R^2(\frac{x_j}{x_1, …, x_{j-1}, x_{j+1}, …, x_p}) = 0$$
# $$Tol(x_j)=1$$

# %% [markdown]
# ## DOMANDA A.34 VARIANZA MULTIFATTORIALE (1 PUNTO)
#
# **Vif (Variance Inflated Factor)** Quanto aumenta il legame con le altre tanto aumenta
#
# $$Vif(x_j)=  \frac{1}{Tol (x_j)} = \frac{1}{1 – R^2
# \frac{x_j}{(x_1,…,x_{j-1}, x_{j+1},…, x_p)}}$$
#   $R^2
# \frac{x_j}{(x_1,…,x_{j-1}, x_{j+1},…, x_p)}$ = coefficiente di determinazione corretto della regressione della variabile in funzione delle altre variabili presenti all’interno del modello.
#
# Se è una variabile  incorrelata con  tutte le altre
# $$Vif(x_j)->             1                    $$
#
# Quanto aumenta il legame con le altre tanto aumenta Vif: se è superiore a 10 si parla di quasi multicollinearità fino a
#
# $$Vif(x_j)->             \infty                   $$
#
# $$Tol(x_j)$$ ha il pregio di essere normalizzato, $$Vif(x_j)$ di estendersi su quasi tutti i reali positivi $(>=1)$
#
# Valori di $Vif(x_j) >10$ indicano come molto probabili problemi a carico del regressore interessato

# %% [markdown]
# ## DOMANDA A.35  LINEARITA’( 3  PUNTI)
#
# La relazione ipotizzata è lineare:  $y = f(x)$
#
# IN BASE AL LEGAME FUNZIONALE TRA PARAMETRI LINEARI:
# la variabile risposta è una combinazione lineare  di variabili esplicative e di parametri lineari
#
# $$y_i = β_0 + β_1w_i + log( β_2 x_i)  +…+ β_r v_i +ε_i$$  Multipla non lineare nei parametri
#
# $$y_i = β_0 + β_1x_i + β_2 x_{i2} +…+ β_r x_i^r + ε_i$$ di grado superiore al 1°non lineare nella variabile $x$
#
# $$y_i = β_0 + β_1x_i + β_2 z_i^2 +…+ β_r k_i^r + ε_i$$  non lineare nelle variabili $z, k$ lineare in $x$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.36 LINEARITA’:RAPPRESENTAZIONI GRAFICHE ( 3  PUNTI)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) Residui vs Valori osservati
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.37 MODELLI NON  LINEARI (  3 PUNTI )
#
# Utilizzando funzioni  non lineari si ha a disposizione una funzione di regressione
#
# $$y_i = f(x_{1i}, x_{2i},…, x_{ki}) + ε_i$$, $i = 1, …, n $
#
# con $f$ funzione non lineare La variazione in $y$ associata a una variazione in $x_1$, mantenendo $x_2, …, x_k$ costanti è in caso lineare
#
# $$Δy_1 = a + b(x_1 + Δx_1)+ cx^2 + … + kx_k) - a - bx_1 – cx_2 - … - kx_k = bΔx_1= ε_1$$
#
# quando $Δx_1=1b$ ci indica il valore di $Δy$
# In caso non lineare:
# $$Δy_{nl1} = f((x_1 + Δx_1)+ cx^2 + … + kx_k) – x_1 + Δx_1)+ cx^2 + … + kx_k) = w_1$$
# ove non si può isolare immediatamente isolare  la variazione $Δx_1$ rispetto a  $x_1$ rispetto

# %% [markdown]
# ## DOMANDA A.38 UTILIZZO FUNZIONI NON  LINEARI(1 PUNTO)

# %% [markdown]
# Data una generica funzione :
# $$				y_i = f(x_{1i}, x_{2i},…, x_{ki}) + ε_i$$, $    i = 1,…, n              $
#
# La variazione in $y$ associata a una variazione in $x_1$, mantenendo $x_2, …, x_k$ costanti è legata all’errore. Quanto è l’errore $ε$  ) ?
#
# Questo e' il criterio di scelta: si utilizza la funzione che minimizza l'errrore $\epsilon$ a parita di numero e tipo di variabili utilizzate (criterio di parsimonia). Se la somma dei quadrati al variare unitario do ogni variabile $\sum ϵ_i^2$ e' piu grande nella funzione lineare della somma dei quadrati al variare unitario di ogni variabile nella funzione non lineare $\sum w_i^2$ si deve utilizzare la funzione non lineare
# $$\sum \epsilon_i^2 \ge \sum w_i^2$$
#
# Per valutare quale sia la   variazione e  per ottenere stime dei parametri occorre capire se le funzioni non lineari siano linearizzabili o meno
#
# ## DOMANDA A.39 MODELLI INTRINSECAMENTE NON LINEARI (2 PUNTI)
#
# Esistono funzioni che non possono essere rese lineari in quanto non esistono trasformazioni che le rendano  tali. Esempi:
# $$y_i = β_0 + β_1x_1/ (1+ (-β_3 x_3)) + ε_i$$
#
# Tali funzioni possono essere stimate con i minimi quadrati non lineari (NLS) ma non in via analitica e  tramite gli OLS.
#
#  Ci si rifà a problemi di minimizzazione non lineare  che si risolvono con algoritmi numerici attraverso appropriati  software in pacchetti statistici o mediante interventi specifici adottati mediante strumenti di statistica computazionale
#
# ## DOMANDA A.40  FUNZIONI LINEARIZZABILI:PARAMETRI ( 1 PUNTO)
# Non sono lineari ma possono essere resi tali
# mediante opportune trasformazioni e poi  stimati tramite OLS.
#
# Si sostituisce il parametro non lineare con uno lineare, si ricavano i risultati e poi si ricava il parametro reale. Si abbia
#
# $$y_i = β_0 + β_1x_i + exp(β_2)z_i  + … + β_rk_i + ε_i  $$
#           $$exp(β_2) = w_2$$
# $$y_i = β_0 + β_1x_i + w_2 z_i  + … + β_rk_i +ε_i$$
# $$\hat{β_2} = ln(\hat{w_2})$$
#
# ## DOMANDA A.41 FUNZIONI LINEARIZZABILI:VARIABILI ( 1PUNTO)
#
# Si sostituisce la variabile non lineare con una lineare e si ricavano parametri
#
# $$y_i = β_0 + β_1x_i + β_2 x_i^2 + … + β_r x_i^r + ε_i$$
#
# Ponendo $x^2 = k e .x^r = w$ si ha:
#
# $$y_i = β_0 + β_1x_i + β_2k_i  + … + β_rw_i + ε_i$$
#
# Si calcolano le soluzioni $\hat{β_0}, \hat{β_1}, \hat{β_2}, …, \hat{β_r}$ come nel modello lineare multiplo OLS  e si ottiene:
#
# $$y_i = \hat{β_0} + \hat{β_1}x_i +\hat{β_2}x_i^2 + … + \hat{β_r}x_i^r + ε_i$$
#
# Una volta linearizzate le funzioni la stima e l’inferenza procedono in modo analogo a quella del modello di regressione lineare multiplo.
#
# Nella realtà non viene proposta una funzione: si hanno i dati e si deve scegliere quale funzione è più opportuno usare secondo il criterio della minimizzazione dell’errore Le possibilità sono evidentemente infinite, sia nella scelta delle variabili che nella scelta di
#
#
# ## DOMANDA A.42 FUNZIONI LINEARIZZABILI PIU’ COMUNI  ( 2 PUNTI)
#
# Si propongono alcune delle più comuni funzioni linearizzabili

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Comporta più problemi trasformare $X$ che $Y$ ; Se Il campo di variazione di una variabile è molto largo la trasformazione logartmica spesso aiuta
# 1.	Polinomiali in $X,Y$ (caso 1, 4)
# 2.	Trasformazioni logaritmiche (caso 2,3)
#
# La variabile dipendente $Y$ viene trasformata in una quadratica, una cubica o una polinomiale di grado più alto;  la funzione di regressione nelle $X$ viene approssimata da una quadratica, una cubica o una polinomiale di grado più alto
#
# ## DOMANDA A.43 POLINOMIALI LINEARIZZABILI NELLE VARIABILI ( 1 PUNTO)
#
#
# La variabile dipendente $Y$ viene trasformata in una quadratica, una cubica o una polinomiale di grado più alto;  la funzione di regressione nelle X viene approssimata da una quadratica, una cubica o una polinomiale di grado più alto
# Approssimiamo la funzione di regressione con una polinomiale:
# 	$$Y_i = β_0 + β_1x_i + β_2 x_i^2 +…+ β_r x_i^r + ε_{ii}$$
# i regressori sono potenze della $X$
#
# Per stima, verifica ipotesi,si procede come nel modello di regressione multipla con OLS
# I coefficienti sono difficili da interpretare, ma la funzione risultante è interpretabile
#
# ## DOMANDA A.44 FUNZIONI LOGARITIMICHE (4 PUNTI)
#
# Le y e/o le X vengono  trasformate prendendone il logaritmo, che ne dà un’approssimazione “percentuale” utile in molte applicazioni
# La regressione diventa lineare sulla(e) nuova(e) variabile(i) ln(y) e/o ln(x).
#   i coefficienti possono essere stimati attraverso l’OLS.
# Stima e inferenza procedono in modo analogo a quella del modello lineare  classico
# La scelta della specificazione (forma funzionale) deve essere guidata da quale interpretazione ha più senso per l’applicazione di interesse, da test e dall’analisi grafica dei valori predetti
# Vi sono  tre casi che differiscono in base  alle variabili y e/o x  trasformate o meno  in logaritmi. Le trasformazioni logaritmiche permettono di modellare le relazioni in termini “percentuali” (come l’elasticità) invece che linearmente
#
# $I.    lineare-log$	$y_i = β_0 + β_1ln(x_i) + ε_i                                $
#
#
# $II.   log-lineare$	$ln(y_i) = β_0 + β_1x_i + ε_i$
# $III.  log-log$	$ln(y_i) = β_0 + β_1ln(x_i) + ε_i                     $
#
# L’interpretazione del coefficiente angolare è diversa in ciascun caso  e risponde al voler  predire la variazione in y per una data variazione in $x$.

# %% [markdown]
# ## DOMANDA A.45 MODELLO  LINEAR LOG (4 PUNTI)
# Si ha $y = β_0 + β_1ln(x) + ε_i$
#
# $y + Δy = β_0 + β_1ln(x + Δx) + ε_i$
#
# Perciò: $Δy = β_1[ln(x + Δx) – ln(x)]$
#
# ove:       $ln(x + Δx) – ln(x) ≅ Δx/x$
#
# Quindi: $Δy ≅ β|_1Δx/x$
#
# Ad un incremento  in x dell 1% in ln $x$  si associa un  incremento $Δy$ di  $β_1$ in  $y$ con $β_1$ coefficiente di elasticità
#
#
# ## DOMANDA A.46 MODELLO  LOG LINEARE (4 PUNTI)
#  Si ha:  $ln(y) = β_0 + β_1x +ε_i$
#
# Perciò :	$ln(y + Δy) = β_0 + β_1(x + Δx)+ ε_i$
#
# Da cui:	$ln(y + Δy) – ln(y) = β_1Δx$
#                                                             $        Δy/y ≅ β_1 Δx$
#
# A un incremento  $Δx$  di $1$ si associa  un incremento $β_1$ $Δy/y$  $(0.01 β_1)$
#
# ## DOMANDA A.47  MODELLO  LOG LOG (4 PUNTI)
#
# Dato $ln(yi) = β_0 + β_1ln(x_i) + ε_i$
#
# $ln(y + Δy) = β_0 + β_1ln(x + Δx) + ε$
#
# si ha:    $ln(y + Δy) – ln(y) = β_1[ln(x + β_x) – ln(x)]$
#
# Da cui
# $Δy/y ≅ β_1Δx/x$
# A un incremento dell’1% in $x$  si produce un  incremento $β_1$ $Δy/y$ ($β_1$ 0.01)
#
# ## DOMANDA A.48  TRASFORMAZIONI NON LINEARI: SINTESI  ( 4  PUNTI)
#
# Lineare $Δx =1  Δy = β_1$
#
# Casi polinomiali  : $Δx = 2 Δy^2  = 2β_1$
#
# Casi polinomiali  : $Δx^2 = 2  Δy   =4 β_1$
#
# Linear-log:   $Δx/x =1%$  $Δy ≅ β_1Δx/x$
#
# Log-lin  Δx=1 Δy/y ≅ β1 Δx
#
# Log-log  $Δx/x =1%$   $Δy/y ≅ β_1$ $Δx/x$
#
# ESPRIMERE IL LEGAME TRA X e Y IN TERMINI DI VARIAZIONI E VARIAZIONI PRECENTUALI SIGNIFICA INTERPRETARE LA NUVOLA DI PUNTI SU CUI SI EFFETTUA L’INTERPOLAZIONE PERCHE’ L’INCREMENTO DI Y RISPETTO A X PUO’ ESSERE ANALIZZATO A PARTIRE DALLA VARIAZIONE ASSOLUTA O PERCENTUALE DI Y SU X
#
# ## DOMANDA A 49   NON NORMALITA’ ( 1 PUNTO)
#
# Quando si adotta uno schema di campionamento casuale di tipo semplice gli errori ei al variare del campione sono identicamente e identicamente   distribuiti in modo normale N(0, σ2) si posso ricavare la distribuzione degli stimatori e ricavare test statistici, intervalli di confidenza ad essi adatti nonché ricavare proprietà ottimali
# In campioni sufficientemente larghi per il teorema del limite centrale proposto da  Theil (1978) la  distribuzione degli errori  tende asintoticamente alla normalità ( di solito si prende n = 25 come punto di riferimento) Per campioni più piccoli se ciò non accade  non è possibile applicare tests e intervalli di confidenza  basati  sull’ipotesi di normalità degli errori.
#
# ## DOMANDA A.50  NON NORMALITA’:CONSEGUENZE  ( 2 PUNTI)
#
# 1. errori non sono più distribuiti normalmente  e anche le loro stime B
#
# 2. Non è più possibile ricavare test basati su normale standardizzata, t di Student e F di Snedecor per i parametri  e test sull’adattamento del modello basati su  F di Snedecor
# 3. Non è più possibile ricavare intervalli di confidenza per i parametri basati sulla normale standardizzata ( quando si conosce la varianza della popolazione), sulla t di Student
# 4. Le stime OLS  non coincidono con le stime ML perché ciò vale solo con la normalità
# 5. Si hanno problema computazionali perché le stime ottenute con i pacchetti statistici

# %% [markdown]
# ## DOMANDA A.51  PROPRIETA’  STIMATORI CON ERRORI   NON NORMALI ( 1 PUNTO)
#
# Per gli stimatori OLS, non essendo più equivalenti agli stimatori di massima verosimiglianza, non vale più il teorema di Cramer-Rao
#
# Quindi gli stimatori OLS non sono più  gli stimatori corretti a minima varianza fra tutti gli stimatori corretti (VUE)
#
# Tuttavia gli stimatori OLS rimangono corretti
# $$E[\hat{B}] = E(X’X)^{-1}X’y = (X’X)^{ -1}XE(y) = (X’X)^{-1}X’E(Xβ + ε)=(X’X)^{-1}X’ X E(β) = b     $$
# e, poiché vale anche il teorema di Gauss Markov distribution free
#  rimangono efficienti e BLUE best linear unvue estimators
#
# ## DOMANDA A.52  COME SI INDIVIDUA LA NON NORMALITA’:INDICI ( 1 PUNTO)
#
#
# L’indice S di  simmetria:
# $$S = (E(X-μ)3)^2/(E(X-μ)^2)^3$$
# Quadrato del momento 3^ intorno alla media/ Cubo della varianza
# sotto ipotesi di normalità ha valore atteso  $E(S) = 0$
#
# Quando la distribuzione è simmetrica moda, mediana, media coincidono
#
# L’indice $K$ di  curtosi $$K = E(X-μ)^4/(E(X-μ)^2)^2$$      4^ momento  intorno alla media/ Quadrato  della varianza
# Sotto ipotesi di normalità $K-3$ ha valore  atteso $E(K-3) = 0$
#
# ## DOMANDA A.53 COME SI INDIVIDUA LA NON NORMALITA’: GRAFICI ( 3 PUNTI)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Distribuzione dei residui
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Distribuzione cumulata dei residui
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.54 COME SI INDIVIDUA LA NON NORMALITA’: QQ PLOT (2 PUNTI)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Ascissa: quantili dei residui di distribuzione empirica
# - Ordinata:  probabilità cumulate dei residui di distribuzione normale
# - Bisettrice: quantili corrispondenti a probabilità cumulate dei residui di distribuzioni empiriche e normale Se le probabilità cumulate corrispondenti a uguali qunatili dei residui di distribuzioni empirica e normale sono identici e la spezzata giace sulla bisettrice del piano la distribuzione empirica è normale Dall’analisi grafica del QQ  -plot si vede che in questo caso i residui non risultano normalmente distribuiti.
#
# ## DOMANDA A.55 TEST DI SHAPIRO-WILK  (2 PUNTI)
#
#
# $$W= \frac{[\sum_{i=1}^n \beta_i \epsilon_{(i)}]^2}{\sum_{i=1}^n (\epsilon_i)^2}$$
#
# $W$: numeratore combinazione lineare degli errori in rango  (ordine dal più piccolo al più grande) con $β_i$ costanti generati da media, varianze e covarianze errori costruite in modo  tale che la statistica W  tenda a 1 se i residui provengono da un Normale.
#
# Denominatore: varianze campionarie relative all’ i-esimo errore $ε(i)$ in rango
# W è quindi compreso tra 0 e 1, estremi che corrispondono rispettivamenteal rifiuto (regione di rifiuto)   e  all’accettazione ( regione di accettazione ) dell’ipotesi di normalitàW è molto fortemente asimmetrico e suoi valori e levati  possono portare ugualmente al rifiuto dell’ipotesi di normalità.
#
#
# ## DOMANDA A.56  TEST KOLMOGOROV SMIRNOV (2 PUNTI)
# Di fatto è il modo per tradurre in test i principi del Q-Qplot
#
# 1. L’ intervallo di variazione è suddiviso in classi di uguale ampiezza (quantili x)
#
# 2. Ad ogni classe sono assegnate le frequenze cumulative  della distribuzione empirica da testare N$(x_j)$ e le probabilità cumulate della normale $P(x_j)$ e si calcolano le differenze classe per classe in termine di  probabilità cumulate $|P(x_j)-N(x_j)|$
#
# 3. Si calcola la massima differenza in valore assoluto in termini di  probabilità cumulate
# $D = sup |P(x_j)-N(x_j)|$
#
# 4. Si  ricorre alle apposite tavole per la D
# Se D è grande e il suo p-value  è inferiore a valore critico dato  da  livello di significatività $𝛂$
# l’Hipotesi di normalità è respinta ( regione rifiuto); se è piccolo e il suo p-value è  superiore al valore critico dato  dal  livello di significatività l’ipotesi di normalità è accettata (regione accettazione )
#
# ## DOMANDA A.57 TEST ASIMMETRIA ( 2 punt)
#
#
# Basato sul fatto che la distribuzione della normale è simmetrica e quando è simmetrica l’indice S di  simmetria:
# $$S = (E(X-μ)^3)^2/(E(X-μ)^2)^3$$
# Quadrato del momento 3^ intorno alla media/ Cubo della varianza
#
# sotto $H_0$ di normalità ha valore atteso  $E(S)= 0$.
#
# Bisogna assicurarsi che il campione sia sufficientemente grande  perché il test non riconosce la dipartita dalla distribuzione normale quando il campione è piccolo. Per questo a partire dai dati il valore dell’indice è spesso ottenuto da una simulazione con 1000 iterazioni.
#
# ## DOMANDA A.58   TEST  CURTOSI ( 2 PUNTI)
#
# Test che verifica se  la distribuzione empirica ha la stessa curtosi della normale vale a dire lo stesso modo di crescere e descrescere della normale, verificando se sia sia più “gonfia" o più sottile  di quanto sia la normale. Perciò è basato sull’indice di curtosi
#
# $$K = E(X-μ)4/(E(X-μ)^2)^2$$
# 4^ momento  intorno alla media/ Quadrato  della varianza
#
# Sotto ipotesi di normalità K-3 ha valore  atteso $E(K-3) = 0$
#
# $H_0$: distribuzione normale $H_1$: Non normale
#
# Se $K$ supera una certa soglia cui è associato il livello di significatività 𝛂 prescelto e quindi il suo $p$-value  è inferiore a $𝛂$   si rifiuta l’ipotesi $H_0$  di normalità.
#
# Se $K$ è inferiore a una certa soglia cui è associato il livello di significatività $𝛂$ prescelto e quindi il suo p-value  è superiore a $𝛂$   non si rifiuta l’ipotesi $H_0$  di normalità.
#
#
# ## DOMANDA A.59  SOLUZIONI A VIOLAZIONI NORMALE  ( 2 PUNTI)
#
# Per campioni di valore n maggiore di 25 i  problemi di non normalità si possono risolvere ricorrendo  al  teorema del limite centrale
#
# Per campioni di valore n minore  di 25 i  problemi di non normalità possono essere risolti usando una trasformazione della variabile y.
#
# La trasformazione può migliorare la relazione lineare tra la variabile dipendente e le variabili indipendenti. La maggior parte dei programmi software consentono di trasformare facilmente la Partendo dal modello lineare semplice y =  bx ( per semplicità senza intercetta)Una breve lista delle principali trasformazioni è:
# 1. $Z = log y$ (con y>0) Si usa quando sε cresce con y, o se  la distribuzione dell’errore ha una asimmetria positiva
# 2. $w = y^2$ Si usa se $s_ε$ è proporzionale a $E(y)$ nei diversi campioni o se la distribuzione dell’errore ha asimmetria negativa
#
# 3. $v = y^{1/2} (con y > 0)Si usa quando $s_ε$ è proporzionale a $E(y)$ nei diversi campioni
# 4. $v = 1/y$ Si usa quando sε cresce significativamente al crescere di y nei diversi campioni
# variabile $y$
#
# ## DOMANDA A.60 OUTLIERS  (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Il criterio dei minimi quadrati $$min Σ_i(y_i –bx_i)^{’2}= min Σ_iε_i^2 = min ε’ε= min(y-X b)’(y-X b)$$
#
# su cui si basano regressioni semplici e multiple è  basato su valori medi e quindi bastano pochi valori lontani dalla media per cambiare completamente i risultati

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.61 COME INDIVIDUARE GLI OUTLIER :GRAFICI (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.62. SCATTER PLOT: DISPERSIONE  ( 1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.63 SCATTER PLOT: ETEROSCHEDASTICITA’ ( 1 PUNTO)
#
# Eteroschedasticità degli errori :se al variare della $x$ la dispersione degli errori muta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.64 SCATTER PLOT: DIREZIONE ( 1PUNTO)
# Segnala se la relazione tra
# variabile  esplicativa e dipendente
# è positiva o negativa
# Segno coefficiente angolare $b_1$

# %% [markdown]
# ![image.png](data:image/png;base64,...)*italicized text*

# %% [markdown]
# ## DOMANDA A.65 SCATTER PLOT: COEFFICIENTE ANGOLARE  ( 1 PUNTO)
#
# Intensita:
# Segnala l’intensità della relazione tra variabile esplicativa e variabile dipendente
# Valore coefficiente angolare b1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DOMANDA A.66 SCATTER PLOT: LINEARITÀ (1 PUNTO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Segnala  se la relazionetra variabile esplicativa e variabile dipendente è lineare o non lineare  (e linearizzabile)Confronto con andamento altre funzionie tra gli $R^2$ (se passando a funzioni non lineari R2 aumenta )

# %% [markdown]
# ## DOMANDA A.67 OUTLIER: RESIDUI STANDARDIZZATI E STUDENTIZZATI
#
# Sia data la matrice di proiezione H
# $$H = X(X’X)^{-1}X’$$			(n,n)
#
# che determina la capacità del modello lineare di predire la variabile dipendente $y$
# come si vede nella risoluzione  modello lineare con parametri OLS
# $$y = XB + ε = X (X’X)^{ -1}X’y + ε = Hy + ε = Hy + (I-H)y$$
# Perciò:
# $$e = (I-H)y$$
# $$var (ε) = y’(I-H)y$$
# Sia hii l’elemento (i,i ) sulla diagonale principale  di H, denominato leverage (effetto leva)che verifica l’impatto che l’osservazione i ha sulla capacità del modello di predire y
#
# la varianza della singola osservazione i può essere quindi scritta come $$var(εi) = (1- h_{ii}) σ^2$$ Si definiscono così i residui standardizzati:
# $$ε_i*= ε_i /σ √(1- h_{ii})$$
# residui di ogni osservazione divisi per lo scarto quadratico medio generale e il rispettivo scarto quadratico medio dell’osservazione stessa In un campione distribuito normalmente, Il  95% degli residui standardizzati sono compresi tra -2 e +2 ed il 99% tra
#
# -2,5 e + 2,5: un osservazione con un valore di 3 probabilmente è un outlier.Se più dell’1% dei casi osservati ha valori assoluti di residui standardizzati maggiori di 2,5, il fit è basso, se più del 5% hanno valori assoluti   maggiori di 2, allora il fit è molto basso.

# %% [markdown]
# ## DOMANDA A.68 OUTLIER: LEVERAGE VALUES (1 PUNTO)
# La Matrice di proiezione $$H = X(X’X)^{-1}X’$$
# stessa
#                                  può essere utilizzata per  verificare la presenza di outlier
#
# Valori elevati di di hii vicini a 1 segnalano che l’osservazione i ha un effetto predominante sulla capacità di predire del modello.
#
# Sia dato il valore medio del  leverage  $(k + 1)/n$
# con k numero delle variabili esplicative, n numero osservazioni.
# $$h_{ii} >2(k + 1)/n$$ o $$h_{ii} >3(k + 1)/n$$ sono valori di soglia: individua  osservazioni potenzialmente anomale con un elevato effetto di leva vale a dire   eccessiva influenza  sulla capacità complessiva  di predire del modello
#
# ## DOMANDA A.69 OUTLIER: COVRATIO (1 PUNTO)
#
# Gli indici complessi sono tutti jacknife basati tutti sull’eliminazione
# della $i$-esima osservazione dal data set
# La Covratio misura la variazione nel determinante della matrice delle covarianze delle stime eliminando la i-esima osservazione.
#
# Quando lo scostamento del determinante eliminando l’osservazione  è elevato l’osservazione  i è anomala
# Il valore soglia per giudicare l’anomalia è $1 ± 3((k + 1)/n)^{1/2}$
#
# ## DOMANDA A.70 OUTLIER: DFITTS (1 PUNTO)
# Misura l’influenza dell’i-esima osservazione sulla stima dei coefficienti di regressione e sulla loro varianza, eliminandola dal dataset. Quando lo scostamento dei coefficienti di regressione eliminando l’osservazione  è elevata l’osservazione  i è anomala
#
# Osservazioni con valori elevati di DFITTS sono quindi da considerarsi outlier
#
# ## DOMANDA A.71  OUTLIER: DFBETA ( 1 punto)
#
# Misura l’influenza dell’iesima osservazione sulle stime di ogni coefficiente di regressione separatamente, eliminandola dal dataset.
#
# Quando lo scostamento di ogni  coefficienti di regressione eliminando l’osservazione  è elevata l’osservazione  i è anomala Valori elevatidi **Dfbetas**  indicano quindi osservazioni che influiscono molto sulla stima dei parametri e sono outlier
#
# Il valore di soglia  prende il valore $2$, o $2(n)^{1/2}$ tenendo conto del numero di osservazioni.
#
#
# ## DOMANDA A.72 OUTLIER: DISTANZA DI COOK ( 1 PUNTO)
# Misura l’influenza misura l’influenza dell’iesima osservazione, sulla stima dei coefficienti di regressione, in termini di capacità del modello di predire tutti i casi eliminandola dal dataset Quando lo scostamento dei coefficienti di regressione eliminando l’osservazione  è elevata l’osservazione i è anomala
#
# Un valore della distanza di Cook maggiore di 1 indica che il punto i è un outlier
#
# ## DOMANDA A.73: PERCORSO PER MODELLO LINEARE  ( 1 PUNTO)
#
# •	1 eliminare collinearità
# •	2 eliminare outlier
# •	3 verificare normalità, sfericità, linearità
# •	4 attuare diverse strategie per vedere se intervenire su una violazione del modello lineare classico risolve i problemi per gli altri
# •	5 se i problemi sono irrisovibili cambiate anche variabili
