# %% [markdown]
# <a href="https://colab.research.google.com/github/NikolayNikolaev1982/GzLM/blob/main/GzLM_Parte_2_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PARTE B MODELLO MINIMI QUADRATI GENERALIZZATI
# Gli errori nel modello illustrato in precedenza sono assunti omoschedastici e incorrelati. Nel seguito si mostrano cosa implicano le violazioni di queste due assunzioni del modello di base.

# %% [markdown]
# ## 1. VIOLAZIONE MODELLO CLASSICO: ETEROSCHEDASTICITÀ

# %% [markdown]
# ### 1.1	Eteroschedasticità
# Si consideri uno studio sul’associazione tra peso e altezza supponendo di disporre di n osservazioni campionarie, il modello si scrive:
#
# $$y=X\hat{B}+\hat{\epsilon} \tag{1}$$
#
# Si ha come si è visto in precedenza:
#
# $$E[\epsilon]= 0 \tag{3}$$
#
# $$Var[\epsilon]= \frac{1}{n} \epsilon' \epsilon \tag{4}$$
#
# Dato il modello (1) si ripetano le osservazioni su diversi campioni 1, 2, …, i, …., n un numero infinito di volte (per convenzione indichiamo con k questo numero di volte). Si considerino gli errori relativi all’individuo nella posizione j-esima di ogni campione $ε_{i1}, ε_{i2}, …, ε_{ik}$. Nel loro complesso tali risultati possono definirsi come determinazione di una variabile casuale $E_i$.
#
# Si possono quindi calcolare oltre al valore atteso le n varianze di ogni variabile casuale $Var(E_i)$ e le $(n^2 - n)$ correlazioni fra variabili casuali diverse $E_i$  e $E_j$.
#
#
#
# $$
# \begin{aligned}
# \text{Individuo 1:} &\quad \varepsilon_{11}^*,\ \varepsilon_{12}^*,\ \ldots,\ \varepsilon_{1j}^*,\ \ldots,\ \varepsilon_{1k}^* \quad \Rightarrow \quad \mathbb{E}_1^* \left[ \text{Var}(E_1^*) \right] = \sigma_1^2 \\\\
# \text{Individuo j:} &\quad \varepsilon_{j1}^*,\ \varepsilon_{j2}^*,\ \ldots,\ \varepsilon_{jj}^*,\ \ldots,\ \varepsilon_{jk}^* \quad \Rightarrow \quad \mathbb{E}_j^* \left[ \text{Var}(E_j^*) \right] = \sigma_j^2 \\\\
# \vdots & \\\\
# \text{Individuo n:} &\quad \varepsilon_{n1}^*,\ \varepsilon_{n2}^*,\ \ldots,\ \varepsilon_{nj}^*,\ \ldots,\ \varepsilon_{nk}^* \quad \Rightarrow \quad \mathbb{E}_n^* \left[ \text{Var}(E_n^*) \right] = \sigma_n^2
# \end{aligned}
# $$
#
# ---
#
# $$
# \text{var}(\varepsilon) = \sigma^2; \quad \text{var}(\varepsilon) = \sigma^2; \quad \text{var}(\varepsilon) = \sigma^2; \quad \text{var}(\varepsilon) = \sigma^2
# $$

# %% [markdown]
# Si ha:
#
# $$ E(E_i ) = E_i  		\tag{5}$$
# $$Var(E_i ) = E(E_i^2) = 𝛔_i 		\tag{6}$$
# $$Cor(E_i, E_j) = 1/n (E_i E_j ’) = 0 	\tag{7}$$
#
# In termini matriciali, omoschedasticità significa che: $E(εε') = σ^2$ In. Come si può intuire in termini generali la varianza (6) della variabile casuale $E_j$  relativa al j-esimo elemento di ogni campione non può che essere diversa dalla varianza di ogni altra variabile $E_k$ perché ad esempio la varibilità di peso e altezza varia da individuo a individuo ed è quindi altamente improbabile che al variare del campione gli elementi $ε_{i1}, ε_{i2}, …, ε_{ik}$, per $i = 1,2, …, n$ siano tutti uguali.
#
# Modello con errori errori eteroschedastici incorrelati. In termini matriciali con omoschedasticità si ipotizza $$E(εε') = σ^2 I_n \tag{8}$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In caso di eteroschedasticità la varianza dell’errore diviene: $E(e_i^{*2}) = σ_i^2$ e in forma matriciale $E(e*e*’) = σ_i^2$ In dove $e*$ denota l’errore eteroschedastico per distinguerlo da quelli sferico. Nel caso di errori eteroschedastici, valutiamo l’impatto sulle proprietà degli stimatori OLS.
#
# $$E[E_i^*]=0 \tag{9}$$
#
# $$Var[E_i^*]=E[E_i^{*2}]=\sigma_i^2 \tag{10}$$
#
# $$Cor(E_i, E_j)=\frac{1}{n}(E_iE_j')= 0 \tag{11}$$
#
# $Cor(E_1^*, E_i^*)= 0$
#
# $$Cor(E_i^*, E_n^*)= 0$$
#
# Errori omoschedastici e incorrelati
#
#
#
# dove:
#
# $$
# \mathbf{\sum}_n =
# \begin{bmatrix}
# \sigma^2 & 0 & 0 & \cdots & 0 \\
# 0 & \sigma^2 & 0 & \cdots & 0 \\
# 0 & 0 & \sigma^2 & \cdots & 0 \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & 0 & \cdots & \sigma^2
# \end{bmatrix} = \sigma^2 I_n
# $$
#
# Errori eteroscedastici e incorelati:
#
# $$
# \mathbf{\sum}_n =
# \begin{bmatrix}
# \sigma_{(1)}^2 & 0 & 0 & \cdots & 0 \\
# 0 & \sigma_{(2)}^2 & 0 & \cdots & 0 \\
# 0 & 0 & \sigma_{(3)}^2 & \cdots & 0 \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & 0 & \cdots & \sigma_{(n)}^2
# \end{bmatrix} = \sigma^2 I_n
# $$

# %% [markdown]
# ### 1.2 Errori eteroschedastici e proprietà degli stimatori
#
# Lo stimatore eteroschedastico di denota con B* ed ha le seguenti proprietà:
#
# - Correttezza:
#
# $$E[B*] = E(X’X)^{-1}X’y = (X’X)^{-1} X E(y) = (X’X)^{-1}X’ E(X b + e*) =$$
# $$=(X’X)^{-1}X’X E(b) = b 		\tag{14}$$
#
# - Consistenza è ancora valida ed è possibile dimostrarlo;
#
# - Efficienza non è più valida e quindi non è più BLUE. Infatti:
#
# $$Var(B*) = E(((X’X)^{-1}X’) y - b)((X’X)^{-1}X’)y-b))’=$$
# $$E(((X’X)^{-1}X’)(Xb + e*) - b)((X’X)^{-1}X’)(Xb + e*) - b))=$$
# $$E(((X’X)^{-1}X’) e*)((X’X)^{-1}X’) e*)’=$$
# $$ (X’X)^{-1} X’)E(e*e*’)( X’X))^{-1}X’)’ =$$
# $$((X’X)^{-1} X’)Σe*(( X’X)^{-1}X’)’			\tag{15}$$
#
# Poiché non si conosce la varianza della popolazione non si può usare la varianza campionaria $s^2$ e le stime campionarie tendono a sottostimare il vero valore della varianza $σ_i^2$, non esiste più un’unica varianza da stimare $σ^2$ ma molteplici. Sottostimando il vero valore della varianza campionaria, la statistica test $t$ di Student ha valori elevati ed il test risulta distorto rendendo significativi i parametri che in realtà non lo sono. Allo stesso modo, gli intervalli di confidenza tendono ad essere più stretti e quindi meno affidabili.
#
# Ricordiamo che il test con la distribuzione della statistica test come una t di di Student (ci si riferisce in questo caso l’individuo i) è dato da
#
# $$t=\frac{\beta_j}{\frac{s}{\sqrt{n\sigma_{jj}^{-1}}}}$$
#
# che in caso di errori eteroschedastici il valore
#
# $$t=\frac{\beta_j}{\frac{s}{\sqrt{n\sigma_{jj}^{-1}}}} \tag{16}$$
#
# varia al variare delle osservazioni e mostra dei coefficienti significativi anche quando in realtà non lo sono. La regione di accettazione del test è così configurata
#
# $$P[-t_{\frac{\alpha}{2}}\frac{s}{\sqrt{n\sigma_{jj}^{-1}}} < \beta_j < t_{\frac{\alpha}{2}}\frac{s}{\sqrt{n\sigma_{jj}^{-1}}}]= 1-\alpha$$
# - intervallo causuale di fiducia
#
# In caso di eteroschedasticità si ha:
#
# $$P[-t_{\frac{\alpha}{2}}\frac{s}{\sqrt{n\sigma_{jj}^{-1}}} < \beta_j < t_{\frac{\alpha}{2}}\frac{s}{\sqrt{n\sigma_{jj}^{-1}}}]= 1-\alpha$$
#
# Come si vede la regione di accettazione e quindi di rifiuto varia per ogni osservazione e se si sottostima $σ$ la regione di accettazione stessa è più piccola di quanto non sia in realtà e la regione di rifiuto è più grande di quanto non sia in realtà.
#
# Analogo ragionamento può essere fatto per il test $F$ sui singoli parametri che come si è visto è pari a:
#
# $$F= \frac{\chi_{(1)}^2}{\chi_{(n-p-1)}^2}= \frac{\beta_j^2}{\frac{s^2}{n\sigma_{jj}^{-1}}}\sim F_{1; n-p-1}$$
#
# ed è quindi pari al quadrato del test $t$ ed è quindi in questo caso pari a:
#
# $$[\frac{\beta_j}{\frac{s^{1*}}{\sqrt{n\sigma_{jj}^{-1}}}}]^2$$
#
# Per la stessa ragione, gli intervalli di confidenza costruiti risultano essere più piccoli di quanto non siano in realtà e quindi l’intervallo di confidenza al cui interno con probabilità $1-α$ sta il valore vero del parametro è ritenuto erroneamente più stretto di quanto non sia in realtà.
#
# La presenza di errori eteroschedastici può essere identificata anche mediante un’analisi grafica e dei test statistici.

# %% [markdown]
# ##
# ## 1.3 Valutazione di eteroschedasticità
#
# ### 1.3.1 Analisi Grafica
#
# #### Primo approccio
# Un primo grafico è il diagramma a dispersione che riporta i valori osservati della variabile dipendente rispetto ai valori osservati per una certa covariata. C’è presenza di eteroschedasticità se al variare delle osservazioni della covariata (asse x) varia la dispersione dei valori della risposta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (asse y). Nel caso di un modello di regressione lineare multipla con più di un regressore si devono considerare i diagrammi a dispersione per ogni covariata.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Secondo approccio
# Un altro grafico molto utile è formato ponendo in ascissa i valori previsti dal modello per la variabile dipendente ed in ordinata i residui stimati. C’è eteroschedasticità se la dispersione dei residui varia al variare dei valori previsti. Vi è però un’eccezione nei piccoli campioni (pannello in alto a destra), infatti gli errori tendono ad essere più grandi in prossimità della media della variabile dipendente.
#
# #### Terzo Approccio
# Un altro grafico è quello dei residui al quadrato e dei valori previsti. Se c’è omoschedaticità i residui al quadrato formano un ellisse di punti altrimenti si disperdono lungo l’asse delle ascisse.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Quarto approccio
# Un altro grafico è quello dei valori osservati per la risposta e dei valori previsti. La seguente figura a sinistra mostra una situazione di eteroschedasticità, mentre la figura a destra una situazione di omoschedasticità. Se la dispersione dei valori osservati varia al valore dei valori predetti allora c’è eteroschedasticità

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Quinto approccio
# Un altro grafico è quello residui e dei valori osservati per le covariate inserite nel modello.  Anche in questo caso, la dispersione dei punti è segno di eteroschedastcità: nella seguente figura i primi grafici indicano una situazione di eteroschedasticità, mentre nella figura seguente i grafici indicano una situazione di omoschedasticità.
#
#
# #### Eteroscedasticita

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Omoscedasticita

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.3.2 Test statistici
# Oltre all’analisi grafica, è possibile verificare la presenza di eteroschedasticità mediante dei test statistici di vario tipo.  L’assunzione di omoschedasticità dei residui si valuta come:
#   $$ H_0: Var(e|X) = σ^2 In 	 \tag{19}$$
#  $$ H_1: Var(e|X) ≠ σ^2 In	  \tag{20}$$
# dove $X$ è la matrice dei regressori della specificazione che ha dato vita ai residui e $I_n$ è una matrice identità. Il test si basa su una regressione OLS del quadrato dei residui $(e^2)$ sugli stessi regressori del modello che li hanno generati che comprende anche i termini di 2° grado come illustrato nel seguente test.
#
# #### a) Test di White
# **Step1:** Dalla stima del mdoello di regressione si ricavano i residui ei
# $$y_i = b_0 + b_1x_{i1} + b_2x_{i2} + ... + b_px_{ip} + ε_i	\tag{21}$$
#
# **Step 2:** Si calcola la regressione OLS del quadrato dei residui ei sui regressori del modello considerando un’equazione polinomiale del seguente tipo
#
# $$e_i^2 = γ_0 + γ_1x_{i1} + ... + γ_px_{ip} + γ_αx_{i1}^2 + γ_βx_{i2}^2 + … + γ_ζx_{ip} + γ_θx_{i1}x_{i2} + … + γ_κx_{i1}x_{ip}+ … + γ_νx_{i2}x_{ip} + u_i    \tag{22}$$
#
# **Step 3:** Si calcola il coefficiente di determinazione multiplo per la regressione (22) $R_u^2$ e si elabora la seguente statistica:
#
# $$LM = nR_u^2		\tag{23}$$
#
# che si distribuisce come una distribuzione $χ^2$ con gradi di libertà pari al numero dei regressori inseriti nel modello.
#
# **Step 4:** Si verifica l’assunzione di omoschedasticità dei residui, attraverso il test effettuato su (23)
#
# $$H_0: Var(U) = σ^2 	         \tag{24}$$
# $$H_1: Var(U) ≠ σ^2          \tag{25}$$
#
# $H_0$ verrà rigettata qualora LM risulti superiore al valore soglia della distribuzione $χ^2(c)$ riferito al livello di significatività prescelto perché significa che le variabili esplicative sono ancora significative nello spiegare i residui al quadrato elementi che compongono la varianza dei residui stessi. Il che significa che la variabilità dei residui dipende dai valori della variabile dipendente come avviene nel caso di eterosc hedasticità.
#
# #### b) Test di Breusch-Pagan
# Breusch-Pagan suggeriscono un test per l’omoschedasticità più generale in cui non occorre specificare una forma funzionale. Si calcola
# $$s^2 = \frac{Σ_i e_i^2}{n}		\tag{26}$$
# Si effettua la regressione
#
# $$\frac{ε_i^2}{s^2} = f(γ_0 + γ_1 x_{i1} + γ_2 x_{i2} + ... + γ_r x_{ir}) + w_i	 \tag{27}$$
#
# e si calcola la somma dei quadrati dei regressori e degli scarti che si distribuiscono entrambe come $Χ_2$ indipendenti (con gradi di libertà rispettivamente a $n$ regressori $k$ e $n-k$ e quindi come rapporto come una $F$ di Snedecor. L’ipotesi nulla di omoschedasticità dei residui verrà rigettata qualora la statistica il test $F$ risulti superiore al valore soglia della distribuzione riferito al livello di significatività prescelto e si accetta implicitamente che gli errori del modello siano eteroschedastici.

# %% [markdown]
# ## 2: Violazione Modello Classico : Autocorrelazione
#
# Frequentemente i residui risultano correlati, così, soprattutto in serie storiche o territoriali, è ragionevole ipotizzare che esista correlazione fra gli errori del modello di regressione quando si analizzano dati in serie storiche o longitudinali oppure dati spaziali (ad esempio misurazioni su territori vicini). In particolare:
# - I modelli longitudinali sono modelli che permettono di tener conto della dipendenza temporale delle osservazioni;
# - I modelli spaziali sono quelli che modellizzano l’associzione tre le osservazioni dovuta alla distanza territoriale;
#
# Nel modello classico si ipotizza che:
# $$Cov(ε_i, ε_j)= E(ε_i, ε_j) = 0  	\tag{28}$$
# - $∀ i ≠ j$
#
# Quando questa condizione non è veriﬁcata si dice che gli errori sono correlati o che si è in presenza di correlazione seriale. Con omoschedasticità e correlazione seriale la matrice di correlazione degli errori diviene

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si consideri la seguente equazione che postula una dipendenza del primo ordine per gli errori
#
# $$εi** = ρε_{i −1}** + η_i		\tag{29}$$
#
# dove $η_i$ sono variabili i.i.d. con distribuzione di Gauss $N(0, σ_η)$. Pertanto, $ε_i**$ è un processo autoregressivo perché $ε_i**$ dipende dal suo valore ritardato $ε_{i −1}** essendo $ε_i**$  gli errori correlati per distinguerli dagli errori sferici $ε_i$.
#
# Si dice che c’è autocorrelazione se al variare di $x$ si verifica una fluttuazione significativa dei valori di $y$ con lo stesso segno (positiva), o segno alternato (negativa). Si consideri il modello di regressione per spiegare l’associazione tre l’acquisto di una nuova macchina elettrica ed il reddito familiare.
#
# Il fatto di averla acquistata nell’anno 2014 influenza l’acquisto negli anni successivi. Si ripetano le osservazioni per un numero infinito di famiglie $1, 2, …, i , … , k$ negli stessi anni (indicando con k questo numero infinito di famiglie).
#
# Si considerino gli errori nel modello sono i seguenti $ε_{j1}**, ε_{j2}**, …, ε_{ij}**, …. , ε_{jk}**$ ognuno relativo a una famiglia diversa nell’anno $j$. Ognuno di essi è determinazione della variabile casuale $E_j** che si genera al variare delle famiglie. Poiché per ogni famiglia l’aver acquistato la macchina nell’anno 2014 influenza il fatto di acquistarla negli anni successivi e ogni variabile $E_j**$ relativa a un anno è correlata  a ogni altra $E_k**$
#
# $$Cor(E_j**, E_k**) = 1/n (E_j**E_k**’) = ρ_{jk} \tag{31}$$
#
# Ovvero per la famiglia 1 nell’anno 1 e nell’anno n si ha
#
# $$E_1 Var(E_1**) = 𝛔^2$$
# $$E_n Var(E_n**) = 𝛔^2$$
#
# L’equazione del modello di regressione con errori correlati omoschedastici diventa:
#
# $$Y_j = x_j b_j  + ε_i** 		\tag{32}$$
# $$E(E_j**) = 0  	\tag{33}$$
# $$Var(E_j**)  = E(E_j**2) = 𝛔^2		 \tag{34}$$
# $$Cor(E_j**, E_k**) = 1/n (E_j**E_k**’) ρ_{jk} 	\tag{35}$$
#
# Errori eteroschedastici e correlati

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Errori omoscedastici e correlati:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con correlazione uguale tra errori diversi: errori omoschedastici e correlati

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# L’autocorrelazione positiva si ha quando residui consecutivi tendono ad essere dello stesso segno e simili in valore (a sinistra), mentre si parla di autocorrelazione negativa se si hanno residui consecutivi che tendono ad essere di segno differente (a destra)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# L’autocorrelazione può essere anche di grado superiore al primo.
# $$ε_i** = ρε_{i −2}** + η_i----	2° ordine	 \tag{44}$$
# $$ε_i** = ρε_{i −3}** + η_i---	2° ordine 	\tag{45}$$
# $$ε_s** = ρε_{i −s}** + η_i	---s-esimo ordine \tag{46}$$
# Sotto il profilo dell’andamento dei residui la concomitanza di autocorrelazione di diverso ordine porta ad una configurazione più complessa dei residui stessi.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.1 Errori correlati: proprietà
# La correlazione degli errori ha un impatto sulle proprietà degli stimatori OLS?
#
# **Correttezza**: Valgono ancora la correttezza e la linearità che non dipende dalla possibile  autocorrelazione. Dato lo stimatore con osservazioni autocorrelate B**
#
#
# $$E[B**] = E(X’X)^{-1}X’y = (X’X)^{-1}X’ E(y) = (X’X)^{ -1}X’ E(Xb + ε_i**) =
# (X’X)^{-1}X’X E(b) = b.		\tag{47}$$
#
# **Consistenza**: Si dimostra che  vale lo stesso per la consistenza.
#
# **Efficienza**: Lo stimatore B** con errori correlati non è più BLUE e quindi non è efficiente
# $$Var(B**) = E(((X’X)^{-1}X’)y-b)(( X’X)^{-1}X’) y-b))’=
# E(((X’X)^{-1}X’)(Xb + ε_i**) - b)((X’X)^{-1}X’) (Xb + ε_i**) - b)) =
# E((((X’X)^{-1}X’) ε_i**)((X’X)^{-1}X’) ε_i**)’ =
# (X’X)^{-1}X’E(ε_i*ε_i*’) (X’X)^{-1}X’)’ =
#  ((X’X)^{-1}X’)Σ ((X’X)^{-1}X’)’ 		\tag{48}$$
#
# Poiché non si conosce la varianza della popolazione non si può usare la varianza campionaria s2 nella statistica t di Student perché non si può approssimare in modo corretto $σ^2$:
# - La t di Student è costruita sulla base dell’incorrelazione degli errori nella popolazione (rapporto tra somma di normale standardizzata e una Chi-quadrato somma di normali al quadrato identicamente distribuite)
# - Il valore atteso della varianza campionaria $s^2$ non è, in queste condizioni, stima corretta per $σ^2$. Se $ρ$ è positivo, la stima dei parametri sottostima il vero valore dei parametri nella popolazione.
#
# La Statistica t di Student ha valori erroneamente elevati e il test fa sì che vengano ritenuti significativi i parametri che in realtà non lo sono nella popolazione.
# Allo stesso modo, gli intervalli di confidenza per i parametri tendono ad essere più stretti e quindi meno affidabili.
#
# Essendo la regione di accettazione per test del t di Student così configurata

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Come si vede la regione di accettazione e quindi di rifiuto varia per ogni osservazione e se s sottostima σ la regione di accettazione stessa è più piccola di quanto non sia in realtà e la regione di rifiuto è più grande di quanto non sia in realtà.
#
# Analogo ragionamento può essere fatto per il test F sui singoli parametri:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Per la stessa ragione, gli intervalli di confidenza costruiti risultano essere più piccoli di quanto non siano in realtà.

# %% [markdown]
# ## 2.2 Come si individua
# 2.2.1 Rappresentazione grafica
#
# L’approccio grafico consiste in 4 diversi rappresentazioni grafiche per valutare l’autocorrelazione dei residui:
# - 1° Diagramma a disperzione
# - 2° Residui del modello rispetto ai valori osservati nel tempo
# - 3° Residui del modello rispetto ai residui ritardati
# - 4° Correlogramma
#
# ### 1° Grafico: Diagramma a disperzione
#
# Un primo grafico è lo scatterplot dei valori residui del modello e nel tempo. Se si verifica un andamento positivo dei residui alternato con un andamento negativo si è in presenza di una situazione di correlazione positiva di primo ordine e negativa di ordine superiore (caso a sinistra), mentre se i residui oscillano intorno allo zero si ha una situazione di incorrelazione (caso a destra).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Di seguito si riporta un grafico, dove si mostra una Autocorrelazione positiva di 1° ordine, negativa di 2° ordine.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Di seguito si riporta un grafico, dove si mostra una autocorrelazione negativa di 1° ordine.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Di seguito si riporta un grafico, dove si mostra una autocorrelazione positiva di 1° ordine e di ordine  superiore.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Di seguito si riporta un grafico, dove si mostra una autocorrelazione positiva di 1° ordine e negativa di ordine superiore.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Di seguito si riporta un grafico, dove si mostra una autocorrelazione negativa di 1° grado e positiva di grado superiore

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2° Grafico: Residui del modello rispetto ai valori osservati nel tempo
#
# Per ogni regressore

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3° Grafico: Residui del modello rispetto ai residui ritardati
# Il diagramma a dispersione dei valori residui del modello e dei residui ritardati permette di verificare che se gli errori fossero indipendenti, non dovrebbero esserci pattern o strutture nel grafico. In questo caso i punti appariranno casualmente sparsi. Se i residui sono tra loro correlati si evidenziano dei pattern deterministici, come ad esempio una relazione lineare.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4° Correlogramma
# Questo grafico permette di individuare e scomporre con chiarezza le correlazioni di diverso ordine, mostrando le associazioni tra i residui ad un certo lag temporale: autocorrelazione seriale.
# Le bande di confidenza mostrano il limite entro cui non si ritiene vi sia autocorrelazione. Molti coefficienti risultano esterni alle bande di confidenza il che è sinonimo di autocorrelazione seriale.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.2.2 Test: autocorrelazione (o correlazione seriale) di Durbin-Watson
#
# Per verificare la possibile presenza di correlazione nel termine d’errore, si propongono test per la verifica della presenza o meno di correlazione tra i residui campionari in tempi diversi, $ε_i^# , ε_{i-1}^#, ε_{i-2}^#$ e così via. (autocorrelazione o correlazione seriale). Il test di riferimento è il test di Durbin-Watson, dove
#
# $$H_0: ρ = Corr[ε_i**, ε_{i-1}**] = 0		\tag{53}$$
#
# dove $ε_i**, ε_{i-1}**$sono i residui relativi all’osservazione i-esima e quella precedente con
# $$ε_i** = ρ ε_{i-1}** + w_i	 	\tag{54}$$
#
# L’ipotesi nulla sottoposta a verifica è quella di assenza di correlazione seriale del primo ordine,
# $$H_0: ρ = 0$$
#
# La statistica di DW ha la seguente forma:
# $$DW=Σ_i (ε_i**- ε_{i-1}**)2/ Σ ε_i**=			          \tag{55}$$
# $$(E(ε_i**)2+E(ε_{i-1}**)2 – 2 E(ε_i**, ε_{i-1}**))/E(ε_i**)2		\tag{56}$$
#
# per i = 1, … , n e per l’omoschedasticità dei residui:
#
# $$E(ε_{i-1}**) = Var (ε_{i-1}**) = E(ε_i**) = Var (ε_i**) = σ^2_i = σ^2 \tag{57}$$
# e per
#
# $$E(ε_i**, ε_{i-1}**) = E (ρε_{i-1}**+ w_i , ε_{i-1}**) = ρ σ^2 + E(η_i , ε_{i-1}**) = ρ σ^2 	\tag{58}$$
#  in quanto per le proprietà della regressione $E(η_i , ε_{i-1}**) = 0$.
# Perciò
# $$DW= (2σ^2 - 2ρ σ^2)/ σ^2 = 2(1-ρ)		\tag{59}$$
# Si verifica l’assenza di autocorrelazione dei residui con l’ipotesi H0 ovvero ipotesi alternativa che può essere:
# “greater” (a una coda a destra) ovvero unidirezionale destra;
# “less” (a una coda a sinistra) ovvero unidirezionale sinistra;
# “two sided” (a due code) in caso di ipotesi alternativa bidirezionale.
#
# La distribuzione campionaria di DW è:
# - centrata su 2 (DW = 2, ρ = 0) quando c’è incorrelazione;
# - tende a 0 se i residui sono correlati positivamente (DW = 0, ρ = 1);
# - tende a 4 se i residui sono correlati negativamente (DW = 4, ρ = -1).
#
# Vengono fissati dei valori critici pari a dl e du che delimitano le regioni della statistica test sotto l’ipotesi nulla tra regione di rifiuto, regione di incocludenza del test e regione di accettazione.
#
# Test a 2 code per l’autocorrelazione:
# - Se d < dl  c’è sufficiente evidenza per dimostrare che c’è autocorrelazione positiva;
# - Se d > du c’è sufficiente evidenza per dimostrare che c’è autocorrelazione negativa;
# - Se d è tra dl e du non c’è sufficiente evidenza per dimostrare che c’è autocorrelazione.
#
# In generale convenzionalmente, quando non siano specificati, dl e du,
# - se d < 1 c’è sufficiente evidenza per dimostrare che c’è autocorrelazione positiva;
# - Se d > 3 c’è sufficiente evidenza per dimostrare che c’è autocorrelazione negativa;
# - Se d è tra 1 e 3 non c’è sufficiente evidenza per dimostrare che c’è autocorrelazione.

# %% [markdown]
# ## 3. METODO DI STIMA WLS NEL CASO DI ETEROSCHEDASTICITÀ
